# %% [markdown]
# # Quiz

# %%
import numpy as np

def sigmoid(x, w, b):
    return 1/(1+np.exp(-(w*x+b)))

# %%
x = np.asarray([3, 4, 5, 6, 8])
y = np.asarray([0.268, 0.73, 0.952, 0.994, 0.999 ])

# %%
w, b = 0, 0
y_hat = np.asarray([sigmoid(value, w, b) for value in x])
y_hat
# Out:
# array([0.5, 0.5, 0.5, 0.5, 0.5])

# %%
# Calculate the loss
diff = y - y_hat
diff_sqr = np.square(diff)
loss = np.sum(diff_sqr)

print("Average Loss:", loss/len(x))
# Out:
# Average Loss: 0.160813

# %% [markdown]
# # Sigmoid Function

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = 20, 10

# %% [markdown]
# ## Sigmoid with single variable (2D)
# $S_{w,b}(x) = \frac{1}{1+e^-(wx+b)}$

# %%
def sigmoid(x, w, b):
    return 1 / (1 + np.exp(-(w*x+b)))

# %%
# Create the Sigmoid points
w = 0.9
b = 0.1
X = np.linspace(-10, 10, 100)
Y = sigmoid(X, w, b)

# %%
plt.plot(X, Y)
plt.title("Sigmoid Function")
plt.show()

# %% [markdown]
# ## Sigmoid with two variables (3D)
# $S_{w_1,w_2,b}(x_1,x_2) = \frac{1}{1+e^-(w_{1}x_{1}+w_{2}x_{2}+b)}$

# %%
def sigmoid_2d(x1, x2, w1, w2, b):
    return 1 / (1 + np.exp(-(w1*x1 + w2*x2 + b)))

# %%
from mpl_toolkits import mplot3d

# %%
X1 = np.linspace(-10, 10, 100)
X2 = np.linspace(-10, 10, 100)
X1, X2 = np.meshgrid(X1, X2)

# %%
w1 = 0.6
w2 = 0.5
b = 0.2

# %%
Y = sigmoid_2d(X1, X2, w1, w2, b)

# %%
ax = plt.axes(projection='3d')
ax.plot_surface(X1, X2, Y, cmap='viridis')
ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('Y')
plt.show()
