# %% [markdown]
# # Load Dataset

# %%
import sklearn.datasets
import numpy as np

# %%
breast_cancer = sklearn.datasets.load_breast_cancer()
X = breast_cancer.data
y = breast_cancer.target

# %%
X.shape, y.shape
# Out:
# ((569, 30), (569,))

# %%
import pandas as pd

# %%
data = pd.DataFrame(breast_cancer.data, columns=breast_cancer.feature_names)
data['class'] = breast_cancer.target

# %%
data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...    worst texture  worst perimeter  worst area  \
# ...

# %%
data.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
print(data['class'].value_counts())
# Out:
# 1    357
# 0    212
# Name: class, dtype: int64

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop('class', axis=1)
y = data['class']

# %%
X.shape, y.shape
# Out:
# ((569, 30), (569,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, stratify=y) # Stratify is used to make sure that the train and test dataset has equal ratio of all classes.

# %%
y_train.mean(), y_test.mean()
# Out:
# (0.626953125, 0.631578947368421)

# %% [markdown]
# # Binarisation of Input (Since M P Neuron takes in Binary input)

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = 30, 10

# %%
plt.plot(X_train.T, '*')
plt.xticks(rotation='vertical')
plt.show()

# %%
X_binarized_3_train = X_train['mean area'].map(lambda x: 0 if x < 1000 else 1)
plt.plot(X_binarized_3_train, '*')
plt.show()

# %%
X_binarized_train = X_train.apply(pd.cut, bins=2, labels=[1,0])
plt.plot(X_binarized_train.T, '*')
plt.xticks(rotation='vertical')
plt.show()

# %%
X_binarized_test = X_test.apply(pd.cut, bins=2, labels=[1, 0])
plt.plot(X_binarized_train.T, '*')
plt.xticks(rotation='vertical')
plt.show()

# %%
X_binarized_train = X_binarized_train.values
X_binarized_test = X_binarized_test.values

# %%
X_binarized_train.shape, X_binarized_test.shape
# Out:
# ((512, 30), (57, 30))

# %% [markdown]
# # MP Neuron Model

# %%
# Brute force

for b in range(X_binarized_train.shape[1]+1):
    y_pred_train = []
    accurate_rows = 0
    
    for x, y in zip(X_binarized_train, y_train):
        y_pred = np.sum(x) >= b
        y_pred_train.append(y_pred)
        accurate_rows += (y==y_pred)
    
    print(b, accurate_rows/X_binarized_train.shape[0])
# Out:
# 0 0.626953125
# 1 0.626953125
# 2 0.626953125
# 3 0.626953125
# 4 0.626953125
# 5 0.626953125
# 6 0.626953125
# 7 0.626953125
# 8 0.626953125
# 9 0.626953125
# 10 0.626953125
# 11 0.626953125
# 12 0.626953125
# 13 0.62890625
# 14 0.6328125
# 15 0.63671875
# 16 0.64453125
# 17 0.65234375
# 18 0.66015625
# 19 0.666015625
# 20 0.673828125
# 21 0.689453125
# 22 0.708984375
# 23 0.734375
# 24 0.771484375
# 25 0.806640625
# 26 0.833984375
# 27 0.861328125
# 28 0.8515625
# 29 0.818359375
# 30 0.751953125

# %%
from sklearn.metrics import accuracy_score
b = 28

y_pred_test = []
accurate_rows = 0

for x in X_binarized_test:
    y_pred = np.sum(x) >= b
    y_pred_test.append(y_pred)
    
accuracy = accuracy_score(y_pred_test, y_test)

print(b, accuracy)
# Out:
# 28 0.6666666666666666

# %% [markdown]
# # MP Neuron Class

# %%
class MPNeuron:
    def __init__(self):
        self.b = None
        
    def model(self, x):
        return sum(x) >= self.b
    
    def predict(self, X):
        y = []
        for x in X:
            result = self.model(x)
            y.append(result)
        return np.array(y)
    
    def fit(self, X, y):
        accuracy = {}
        
        for b in range(X.shape[1]+1):
            self.b = b
            y_pred = self.predict(X)
            accuracy[b] = accuracy_score(y_pred, y)
            
        best_b = max(accuracy, key = accuracy.get)
        self.b = best_b
        
        print('Optimal Value of b is:', best_b)
        print('Highest Accuracy is:', accuracy[best_b])

# %%
mp_neuron = MPNeuron()
mp_neuron.fit(X_binarized_train, y_train)
# Out:
# Optimal Value of b is: 27
# Highest Accuracy is: 0.861328125

# %%
y_test_pred = mp_neuron.predict(X_binarized_test)
accuracy_test = accuracy_score(y_test_pred, y_test)
print(accuracy_test)
# Out:
# 0.7017543859649122

# %% [markdown]
# # Perceptron Class

# %% [markdown]
# $y = 1, \mbox{if} \sum_i w_i x_i >= b$
#
# $y = 0, \mbox{otherwise}$

# %%
X_train = X_train.values
X_test = X_test.values
y_train = y_train.values
y_test = y_test.values

# %%
class Perceptron:
    def __init__(self):
        self.w = None
        self.b = None
    
    def model(self, x):
        return 1 if np.dot(self.w, x) >= self.b else 0
    
    def predict(self, X):
        y = []
        for x in X:
            result = self.model(x)
            y.append(result)
        return np.array(y)

    def fit(self, X, Y, epochs=5, lr=1):
        self.w = np.ones(X.shape[1], dtype=np.float64)
        self.b = 0
        
        accuracy = {}
        max_accuracy = 0
        
        for i in range(epochs):
            for x, y in zip(X, Y):
                y_pred = self.model(x)

                if y == 1 and y_pred == 0:
                    self.w = self.w + x * lr
                    self.b = self.b + 1 * lr

                elif y == 0 and y_pred == 1:
                    self.w = self.w - x * lr
                    self.b = self.b - 1 * lr
            
            accuracy[i] = accuracy_score(self.predict(X), Y)
            if (accuracy[i] > max_accuracy):
                max_accuracy = accuracy[i]
                chkptw = self.w
                chkptb = self.b
            
        self.w = chkptw
        self.b = chkptb
        
        return accuracy, max_accuracy

# %%
perceptron = Perceptron()

# %%
# %%time
acc_dict, max_acc = perceptron.fit(X_train, y_train, epochs=1000, lr=1E-5)
print('Maximum Accuracy Reached:', max_acc)
plt.plot(acc_dict.values())
plt.ylim(0,1)
plt.show()
# Out:
# Maximum Accuracy Reached: 0.92578125
# Wall time: 5.35 s

# %%
y_pred_train = perceptron.predict(X_train)
print(accuracy_score(y_pred_train, y_train))
# Out:
# 0.923828125

# %%
y_pred_test = perceptron.predict(X_test)
print(accuracy_score(y_pred_test, y_test))
# Out:
# 0.9298245614035088
